# %%
#%%
import os
import numpy as np

import GPy
import GPyOpt

from GPyOpt.methods import BayesianOptimization
#https://nbviewer.org/github/SheffieldML/GPyOpt/blob/master/manual/GPyOpt_external_objective_evaluation.ipynb

# %%
#%%
# SELECT FUNTION 
# function_1, function_2, function_3 ....

function_ = 'function_1' 

print('selected function :', function_ )
# Out:
# selected function : function_1

# %%
#%%

functionsX = {'function_1' : [[0.753627,0.758346],[0.753627, 0.758346],[0.741239, 0.742157],[0.737339, 0.739188],[0.735417, 0.73715],[0.687241, 0.879359],[0.726002, 0.742615],[0.748625, 0.752819],
                              [0.718514, 0.982342],[0.584259, 0.621041],[0.960939, 0.044722]],
              'function_2' : [[0.869851, 0.717543],[0.885227, 0.712664],[0.701541, 0.936788],[0.699507, 0.946349],[0.718496, 0.943443],[0.86575,  0.740114],[0.650556, 0.102694],[0.676746, 0.141022],
                              [0.674585, 0.100889],[0.719808, 0.96008 ],[0.721091, 0.444595]],
              'function_3' : [[0.436884, 0.453066, 0.442615],[0.742412, 0.625096, 0.423735],[0.013604, 0.41805,  0.002959],[0.87024,  0.44147,  0.853325],[0.053941, 0.611792, 0.423061],[0.791606, 0.645307, 0.44204 ],[0.987013, 0.039269, 0.863714],[0.687348, 0.614735, 0.409482],[0.411285, 0.511588 ,0.394986],[0.999031, 0.521639, 0.379081],[0.051268, 0.007585, 0.576179]],
              'function_4' : [[0.426795, 0.479769, 0.340198, 0.377447],[0.393425, 0.385125, 0.281147, 0.447438],[0.483767, 0.515794, 0.046112, 0.382769],[0.342797, 0.533031, 0.47775,  0.396177],[0.519668, 0.39047 , 0.398623, 0.489297],[0.449242, 0.423734, 0.367554 ,0.345862],[0.376501, 0.365869, 0.362371, 0.331985],[0.430146, 0.3755,   0.365214, 0.338847],[0.244654, 0.414485, 0.743178 ,0.014612],[0.028502, 0.363645, 0.355558, 0.01468 ],[0.478612 ,0.773327, 0.539952 ,0.367975]],
              'function_5' : [[0.196419, 0.712628, 0.182004, 0.927412],[0.314736, 0.796046, 0.876858 ,0.909077],[0.653732, 0.919551, 0.884044, 0.886911],[0.802605, 0.958291, 0.90654,  0.913217],[0.846631, 0.982476, 0.941956, 0.881725],[0.972948, 0.959406, 0.926498, 0.959073],[0.962567 ,0.704589, 0.987993, 0.987491],[0.999332, 0.913161, 0.952344, 0.6715  ],[0.051186, 0.001218, 0.060896, 0.048893],[0.976804, 0.835011, 0.575235, 0.987035],[0.871881, 0.040784 ,0.421439, 0.132931]],
              'function_6' : [[0.828527, 0.490185, 0.650857, 0.653384, 0.201982],[0.1879 ,  0.772747, 0.142921 ,0.881072 ,0.299875],[0.405877 ,0.350572, 0.768315, 0.809696 ,0.227878],[0.445104, 0.258952, 0.660093, 0.940312, 0.134045],[0.74181,  0.374745 ,0.967623, 0.947015 ,0.108571],[0.179769 ,0.356094, 0.602267 ,0.905398 ,0.280314],[0.869837, 0.21565,  0.60031,  0.768642, 0.220836],[0.444576, 0.153262, 0.601105, 0.980082, 0.354228],[0.369451, 0.410597 ,0.62238,  0.576199 ,0.063835],[0.182544 ,0.032386, 0.690393, 0.946602, 0.052995],[0.172216, 0.213789, 0.473354 ,0.960516 ,0.142491]],
             'function_7' : [0.36384366313112276,0.36384366313112276,2.4260007022004753,2.455428195886852,2.177793073929895,2.094441487413115,2.619881006244538,0.1439275286427469,2.6696196835086003,
                             2.7095148847475135,0.27695319603177226],
             'function_8' : [6.94185601,6.94185601,7.651350603604101,9.037107654,9.264083347278099,9.44845039,9.679689635,9.789713967,6.94185601,9.276110297,9.279847698]         
            };



#function_ = 'function_8' 
xt1 = np.load(os.getcwd() + f'\\initial_data\\{function_}\\initial_inputs.npy')
xt2 = np.load(os.getcwd() + f'\\initial_data\\{function_}\\initial_inputs2.npy')
xt3 = functionsX[function_]
xt=np.concatenate((xt1, xt2, xt3), axis=0)
yt1 = np.load(os.getcwd() + f'\\initial_data\\{function_}\\initial_outputs.npy')
yt2 = np.load(os.getcwd() + f'\\initial_data\\{function_}\\initial_outputs2.npy')
yt3 = functionsY[function_]
yt=np.concatenate((yt1, yt2, yt3), axis=0)


domain =[]

if(function_ == 'function_1' or function_ == 'function_2'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.0,1)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.0,1)}]
if(function_ == 'function_3'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.0,1)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.0,1)},
             {'name': 'var3', 'type': 'continuous', 'domain': (0.3,.8)}]
if(function_ == 'function_4' or function_ == 'function_5'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var3', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var4', 'type': 'continuous', 'domain': (0.1,0.9)}]
if(function_ == 'function_6'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var3', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var4', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var5', 'type': 'continuous', 'domain': (0.1,0.9)}]
if(function_ == 'function_7'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var3', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var4', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var5', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var6', 'type': 'continuous', 'domain': (0.1,0.9)}]
if(function_ == 'function_8'):
    domain =[{'name': 'var1', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var2', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var3', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var4', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var5', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var6', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var7', 'type': 'continuous', 'domain': (0.1,0.9)},
             {'name': 'var8', 'type': 'continuous', 'domain': (0.1,0.9)}]


# function_1,function_2,function_3,function_4,function_5 ---->> GP
# function_6,function_7,function_8 ----> GP_MCMC

bo_step = GPyOpt.methods.BayesianOptimization(f =None,
                                 domain = domain,
                                 model_type='GP_MCMC',          #- 'GP', standard Gaussian process.
                                                           #- 'GP_MCMC', Gaussian process with prior in the hyper-parameters.
                                                           #- 'sparseGP', sparse Gaussian process.
                                                           #- 'warperdGP', warped Gaussian process.
                                                           #- 'InputWarpedGP', input warped Gaussian process
                                                           #- 'RF', random forest (scikit-learn).
                                 acquisition_type ='MPI_MCMC',   #- 'EI', expected improvement.
                                                           #- 'EI_MCMC', integrated expected improvement (requires GP_MCMC model).
                                                           #- 'MPI', maximum probability of improvement.
                                                           #- 'MPI_MCMC', maximum probability of improvement (requires GP_MCMC model).
                                                           #- 'LCB', GP-Lower confidence bound.
                                                           #- 'LCB_MCMC', integrated GP-Lower confidence bound (requires GP_MCMC model).
                                 acquisition_jitter = 0.05,
                                 X=xt,
                                 Y= yt.reshape(yt.shape[0], 1),
                                 exact_feval=True, 
                                 maximize=True,
                                 batch_size= 1,
                                 acquisition_optimizer_type='CMA', #- 'lbfgs', L-BFGS.
                                                                   #- 'DIRECT', Dividing Rectangles.
                                                                   #- 'CMA', covariance matrix adaptation.
                                 verbosity=True,
                                 normalize_Y= True)
#Y= yt.reshape(yt.shape[0], 1),

x_next = bo_step.suggest_next_locations()
print('next :', x_next)


#bo_step.plot_acquisition()
#bo_step.plot_convergence()
# Out:
# reconstraining parameters GP_regression.rbf
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      6 -6.286615898757476e-02 1.0e+00 4.24e-01  2e-01  2e-01 0:00.4
#     2     12 -6.290831399126513e-02 1.0e+00 4.39e-01  2e-01  2e-01 0:00.9
#     3     18 -6.294027301919997e-02 1.2e+00 3.34e-01  1e-01  1e-01 0:01.3
#    10     60 -6.301337223649457e-02 1.3e+00 2.07e-01  6e-02  7e-02 0:04.5
#    19    114 -6.286619912089340e-02 1.1e+00 1.55e-01  3e-02  4e-02 0:08.5
#    30    180 -2.230871642115921e-01 1.3e+00 4.71e-02  4e-03  5e-03 0:13.9
#    42    252 -5.051954115408270e-01 1.5e+00 1.51e-02  5e-04  6e-04 0:20.0
#    56    336 -5.241084565230372e-01 1.1e+00 2.79e-03  2e-05  3e-05 0:27.3
#    72    432 -5.243868311801756e-01 1.6e+00 4.84e-04  2e-06  2e-06 0:35.4
#    91    546 -5.243868724990258e-01 1.2e+00 2.26e-05  1e-08  1e-08 0:44.8
#   100    600 -5.243868724999019e-01 1.3e+00 7.40e-06  2e-09  2e-09 0:49.3
#   122    732 -5.243868725196339e-01 1.4e+00 1.38e-06  1e-10  1e-10 1:00.5
#   145    870 -5.243868724911552e-01 4.5e+00 7.58e-07  2e-11  8e-11 1:12.2
# termination on tolxstagnation=[1e-09, 20, 0.1] (Sun Jul 21 21:26:43 2024)
# final/bestever f-value = -5.243869e-01 -5.243869e-01 after 871/796 evaluations
# incumbent solution: [0.5836520040615302, 0.6213865900961257]
# std deviation: [7.521396922917786e-11, 2.4718259199639207e-11]
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1